# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II
#
# # ES1
# #### Alumno: Matias Pardo Errecarret

# %% [markdown]
# ## Consigna:
# <img src="./consigna.png" align="center"  />

# %%
from IPython.display import IFrame
IFrame("./es1_res_analitica.pdf", width=900, height=1000)
# Out:
#         <iframe
#             width="900"
#             height="1000"
#             src="./es1_res_analitica.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
"""
Base de @mariano
"""

import sympy as sp
from sympy.abc import s #importamos simbolo s
from IPython.display import display, Math

#Declaro simbolos variables
V1, V2, Vx = sp.symbols("V1, V2, Vx")
G1, G2, Y1, Y2, R3, C = sp.symbols("G1, G2, Y1, Y2, R3, C")

aa = sp.solve([ Vx*(Y1+Y2)-V1*Y1, 
                Vx*(G1+G2) -V1*G1 -V2*G2], 
                [V1, V2])

transf_func = aa[V2]/aa[V1]


# Ejercicio 7.a: Pasatodo de 1er orden

tf7a = transf_func.subs(Y1, s*C)
tf7a = tf7a.subs(Y2, 1/R3)


num, den = sp.fraction(sp.simplify(sp.expand(tf7a)))

num = sp.Poly(num,s)
den = sp.Poly(den,s)

#Obtengo coeficiente de mayor grado del Num y Den LC()
#Lo divido para obtener el coeficiente externo
k = num.LC() / den.LC()

num = num.monic()
den = den.monic()

tf7a_final = sp.Mul(k,num/den, evaluate=True)

print('')
print('################')
print('# Ejercicio 7a #')
print('################')
display(tf7a_final)
# Out:
# ################
# # Ejercicio 7a #
# ################
# (s - G1/(C*G2*R3))/(s + 1/(C*R3))

# %% [markdown]
# ### Normalizacion

# %%
tf7a = tf7a.subs(C, 1)
tf7a = tf7a.subs(R3, 1)

num, den = sp.fraction(sp.simplify(sp.expand(tf7a)))

num = sp.Poly(num,s)
den = sp.Poly(den,s)

#Obtengo coeficiente de mayor grado del Num y Den LC()
#Lo divido para obtener el coeficiente externo
k = num.LC() / den.LC()

num = num.monic()
den = den.monic()

tf7a_final = sp.Mul(k,num/den, evaluate=True)

print('')
print('################')
print('# Ejercicio 7a #')
print('################')
display(tf7a_final)
# Out:
# ################
# # Ejercicio 7a #
# ################
# (-G1/G2 + s)/(s + 1)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as sig
from splane import analyze_sys, pretty_print_lti

#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (15,15)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})

all_sos = []

wo = 1

#G1/G2 Var
G1_div_G2 = [0.5,1,2]

for ii in G1_div_G2:
    
    num = np.array([1,-1*ii]) 
    den = np.array([1, wo])
    
    mi_sos = sig.TransferFunction(num,den)
    
    pretty_print_lti(mi_sos)
    
    all_sos += [mi_sos]
    
#plt.close('all')
analyze_sys(all_sos, sys_name=G1_div_G2)
# Out:
# $\displaystyle \frac{s + -0.5 }{s +   1 }$
# $\displaystyle \frac{s +  -1 }{s +   1 }$
# $\displaystyle \frac{s +  -2 }{s +   1 }$

# %% [markdown]
# ## 5.Utilidad
# Estos circuitos que rotan la fase 180 se podria utilizar para los sistemas balanceados donde una señal se invierte (defasaje de 180) y luego se transmiten de manera diferencial. EL ruido que ingresa en la señal durante la transmision luego se va a cancelar cuando se resten estas dos señales. Caso de ejemplo:
# <img src="./balance_system.png" align="center" />
#
# De todas maneras la aplicacion mas comun para estos circuitos es para corregir el error generado por el retardo de grupo en los medios de enlaces donde dependiendo de la frecuencia de cada señal se transmitira a distintas velocidades generando defasajes y distorsion en la señal de llegada. Este tipo de circuitos que tienen mucho mas control sobre la fase pueden ser usados para contrarestar.
